# %%
from bs4 import BeautifulSoup
from pathlib import Path
import pandas as pd
from tqdm.notebook import tqdm
from joblib import Parallel, delayed
import sys
import json

# Add the 'code' directory to sys.path
project_path = Path(
    'c:/Users/97253/OneDrive/Documents/work/bank of israel/financial division/yossi/tdm sentiment/tdm-sentiment/'
)
sys.path.append(str(project_path / 'code'))

# Import custom modules
from is_economic_model.tdm_parser import TdmXmlParser

def read_file_names_in_chunks(input_file, chunk_size):
    with open(f'{input_file}.txt', 'r') as f:
        chunk = []
        for i, line in enumerate(f, 1):
            file_name = line.strip()
            if file_name:
                chunk.append(file_name)
            if i % chunk_size == 0:
                yield chunk
                chunk = []
        if chunk:
            yield chunk

def xml_to_df(file_path):
    parser = TdmXmlParser()
    soup = parser.get_xml_soup(file_path)
    PROPERTY_TAGS = [
        'GOID', 'SortTitle', 'NumericDate', 'StartPage', 'DocSection', 'mstar', 
        'GenSubjTerm', 'is_economic', 'text_blob_sentiment', 'bert_sentiment', 'WordCount'
    ]
    PROPERTY_NAMES = [
        'GOID', 'Publisher', 'Date', 'Page', 'Section', 'Type', 
        'Tags', 'is_economic', 'text_blob_sentiment', 'bert_sentiment', 'WordCount'
    ]
    content_dict = parser.get_xml_to_dict(
        soup, text=False, property_tags=PROPERTY_TAGS, property_names=PROPERTY_NAMES
    )
    df = pd.DataFrame([content_dict])
    return df

# Initialize variables
data_path = project_path / 'data'
chunk_size = 100

file_names_path = data_path / 'economic_dataset_file_names'

results_path = data_path / 'results'
results_path.mkdir(exist_ok=True)

for i, file_chunk in enumerate(read_file_names_in_chunks(file_names_path, chunk_size)):
    chunk_paths = [data_path / 'data_sample' / file_name for file_name in file_chunk]
    
    # Process files in parallel with a progress bar
    with tqdm(total=len(chunk_paths), desc=f"Processing chunk {i+1}") as pbar:
        results = Parallel(n_jobs=-1, backend='threading')(
            delayed(xml_to_df)(path) for path in chunk_paths
        )
        pbar.update(len(chunk_paths))
    
    # Concatenate results
    if results:
        data = pd.concat(results, ignore_index=True)
        output_file = results_path / f'chunk_{i+1}_data.csv'
        data.to_csv(output_file, index=False)
        del data
# Out:
# Processing chunk 1:   0%|          | 0/100 [00:00<?, ?it/s]
# Processing chunk 2:   0%|          | 0/100 [00:00<?, ?it/s]
# Processing chunk 3:   0%|          | 0/100 [00:00<?, ?it/s]
# Processing chunk 4:   0%|          | 0/100 [00:00<?, ?it/s]
# Processing chunk 5:   0%|          | 0/25 [00:00<?, ?it/s]

# %%
df = pd.read_csv(output_file)
df.head()
# Out:
#    WordCount        GOID            Publisher        Date  Page  \
# 0        744  1022232503  washington post the  2012-06-27  a.17
# 1        623  1442899918  washington post the  2013-10-19   a.8
# 2       1617  1678440923  washington post the  2015-05-05   e.1
# 3        775  1771998110  washington post the  2016-03-11  a.15
# 4        234  1939404332  washington post the  2017-09-17  d.12
#
#                Section                 Type                 Tags  is_economic  \
# 0    editorial-opinion           commentary  political campaigns            1
# 1            a-section                 news            expansion            1
# 2               health  general information                 salt            1
# 3  editorial - opinion           commentary             politics            1
# 4               sports                 news          emmy awards            1
#
#    text_blob_sentiment  bert_sentiment
# 0             0.023113       -0.849715
# 1             0.143159        0.112491
# 2             0.094614       -0.381124
# 3            -0.010533       -0.830004
# 4             0.207219        0.728199

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\97253\OneDrive\Documents\work\bank of israel\financial division\yossi\tdm sentiment\tdm-sentiment\code\results_process

# %%
import pandas as pd
sys.path.append(str(project_path / 'code'))
from salience_index.salience_index import SalienceScorer

# Initialize the scorer
scorer = SalienceScorer()


# Define a function to compute salience score
def compute_salience(row):
    try:
        return scorer.get_salience_score(row['Date'], row['Page'], row['WordCount'], row['Publisher'])
    except Exception:
        return None

# Apply the function to each row
df['SalienceScore'] = df.apply(compute_salience, axis=1)

# Save the updated DataFrame
#df.to_csv('data_with_salience_score.csv', index=False)

#print("Salience scores added successfully.")
df
# Out:
#     WordCount        GOID            Publisher        Date  Page  \
# 0         744  1022232503  washington post the  2012-06-27  a.17
# 1         623  1442899918  washington post the  2013-10-19   a.8
# 2        1617  1678440923  washington post the  2015-05-05   e.1
# 3         775  1771998110  washington post the  2016-03-11  a.15
# 4         234  1939404332  washington post the  2017-09-17  d.12
# 5         200  1993706424  washington post the  2018-02-04   e.3
# 6        1087  2149891732  washington post the  2018-12-02   a.2
# 7         752   409725169  washington post the  2004-12-10  t.21
# 8         452   409731132  washington post the  2005-01-30  e.06
# 9         400   409882336  washington post the  2005-11-10  t.26
# 10        370   409883681  washington post the  2005-10-08  c.07
# 11        865   409927667  washington post the  2006-01-22  e.01
# 12        636   409964788  washington post the  2005-08-10  b.08
# 13         66   410026901  washington post the  2006-02-24  t.04
# 14        594   410138563  washington post the  2007-07-26  a.20
# 15        334   410159212  washington post the  2007-08-30   t.3
# 16        270   410172286  washington post the  2007-12-05   b.2
# 17       1045   410271228  washington post the  2008-01-30   c.5
# 18        340   410304651  washington post the  2009-02-21   e.7
# 19        369   410323492  washington post the  2009-11-27  t.46
# 20        668   742633964  washington post the  2010-08-13   a.2
# 21        968   755900909  washington post the  2010-10-01  a.18
# 22        520   893725652  washington post the  2011-09-22   t.9
# 23        577   894525606  washington post the  2011-09-29   c.3
# 24        604   923420398  washington post the  2012-02-26   t.2
#
#                 Section                 Type  \
# 0     editorial-opinion           commentary
# 1             a-section                 news
# 2                health  general information
# 3   editorial - opinion           commentary
# 4                sports                 news
# 5                  arts                 news
# 6             a-section                 news
# 7               weekend                 news
# 8                sports                 news
# 9      montgomery extra                 news
# 10                style                 news
# 11               sports           commentary
# 12                metro                 news
# 13              weekend                 news
# 14            editorial           commentary
# 15                    3                 news
# 16                metro                 news
# 17                style                 news
# 18               sports                 news
# 19              weekend                 news
# 20            a section                 news
# 21            a section           commentary
# 22         local living              feature
# 23                style  general information
# 24               extras                 news
#
#                                            Tags  is_economic  \
# 0                           political campaigns            1
# 1                                     expansion            1
# 2                                          salt            1
# 3                                      politics            1
# 4                                   emmy awards            1
# 5                                       critics            1
# 6                            public prosecutors            1
# 7                                           NaN            1
# 8                                           NaN            1
# 9                                           NaN            1
# 10                                          NaN            1
# 11  college basketball -- georgetown university            1
# 12                          political campaigns            1
# 13                                          NaN            1
# 14                       fuel economy standards            1
# 15                                          NaN            1
# 16                                    shootings            1
# 17                      nonprofit organizations            1
# 18                  tournaments & championships            1
# 19                                          NaN            1
# 20                              gays & lesbians            1
# 21                     renovation & restoration            1
# 22                                   herbicides            1
# 23                                          NaN            1
# 24                                          NaN            1
#
#     text_blob_sentiment  bert_sentiment  SalienceScore
# 0              0.023113       -0.849715          0.222
# 1              0.143159        0.112491          0.214
# 2              0.094614       -0.381124          0.470
# 3             -0.010533       -0.830004          0.230
# 4              0.207219        0.728199          0.068
# 5              0.147917       -0.010957          0.070
# 6              0.074623       -0.318708          0.491
# 7              0.071644        0.559390          0.160
# 8             -0.000986        0.487578          0.126
# 9              0.160951        0.603183          0.090
# 10             0.094056       -0.338820          0.113
# 11             0.209003        0.280971          0.361
# 12             0.186799       -0.579161          0.166
# 13             0.500000       -0.953886          0.016
# 14             0.069413       -0.494725          0.182
# 15             0.075407        0.973964          0.091
# 16             0.050641       -0.739568          0.099
# 17             0.169365        0.506528          0.254
# 18             0.093750        0.257216          0.087
# 19             0.036053       -0.999348          0.084
# 20             0.036379       -0.057388          0.260
# 21             0.082393       -0.289434          0.278
# 22             0.061500       -0.804290          0.115
# 23             0.109917        0.149917          0.177
# 24             0.152602       -0.015987          0.231
