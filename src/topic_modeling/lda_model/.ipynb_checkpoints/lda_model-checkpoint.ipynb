# %%
from bs4 import BeautifulSoup
from pathlib import Path
import pandas as pd
from tqdm.notebook import tqdm
from joblib import Parallel, delayed
import sys

# Add the 'code' directory to sys.path
project_path = Path(
    '/home/ec2-user/SageMaker/david/tdm-sentiment/'
)
data_path = project_path / 'data/'
data_sample = Path('/home/ec2-user/SageMaker/data/')
sample_name = 'lda_sample' #  StartupSentiment  'USATodayDavid' 'ChicagoTribune' 'TheWashingtonPostDavid' Newyork20042023' LosAngelesTimesDavid 
sys.path.append(str(project_path / 'code'))

# Import custom modules
from tdm_parser.tdm_parser import TdmXmlParser

def read_file_names_in_chunks(input_file, chunk_size):
    with open(f'{input_file}.txt', 'r') as f:
        chunk = []
        for i, line in enumerate(f, 1):
            file_name = line.strip()
            if file_name:
                chunk.append(file_name)
            if i % chunk_size == 0:
                yield chunk
                chunk = []
        if chunk:
            yield chunk

def xml_to_df(file_path):
    parser = TdmXmlParser()
    soup = parser.get_xml_soup(file_path)
    PROPERTY_TAGS = [
        'GOID', 'SortTitle', 'NumericDate', 'DocSection', 'mstar', 
        'GenSubjTerm', 'StartPage', 'is_economic', 'bert_sentiment', 'WordCount'
    ] 
    PROPERTY_NAMES = [
        'GOID', 'Publisher', 'Date', 'Section', 'Type', 
        'Tags', 'Page', 'is_economic', 'bert_sentiment', 'WordCount'
    ]
    content_dict = parser.get_xml_to_dict(
        soup, property_tags=PROPERTY_TAGS, property_names=PROPERTY_NAMES
    )
    df = pd.DataFrame([content_dict])
    return df

# Initialize variables
data_path = project_path / 'data/'
chunk_size = 1000 
data_chunks = []


file_names_path = data_path / 'file_names' / sample_name #'economic_dataset_file_names' #TODO


for i, file_chunk in enumerate(read_file_names_in_chunks(file_names_path, chunk_size)):
    chunk_paths = [data_sample / file_name for file_name in file_chunk]
    
    # Process files in parallel with a progress bar
    with tqdm(total=len(chunk_paths), desc=f"Processing chunk {i+1}") as pbar:
        results = Parallel(n_jobs=6, backend='threading')(
            delayed(xml_to_df)(path) for path in chunk_paths 
        )
        pbar.update(len(chunk_paths)) 
    
    # Concatenate results
    if results:
        print(results[:2]) #TODO
        data = pd.concat(results, ignore_index=True)
        data_chunks.append(data)  # Append the resulting DataFrame to the list
        
        
# Concatenate all DataFrame chunks into one DataFrame after the loop
data = pd.concat(data_chunks, ignore_index=True)
print(data.head())
# Out:
# Processing chunk 1:   0%|          | 0/1000 [00:00<?, ?it/s]
# [                                                Text WordCount       GOID  \
# 0  [the legislature on thursday ratified agreemen...      1314  421304854
#
#            Publisher        Date             Section  Type     Tags Page  \
# 0  los angeles times  1998-08-28  part-a; metro desk  news  casinos    3
#
#   is_economic        bert_sentiment
# 0           1  -0.44620480213120745  ,                                                 Text WordCount       GOID  \
# 0  [carl pohlad, 93, the longtime owner of baseba...       283  422280280
#
#            Publisher        Date                         Section  Type  \
# 0  los angeles times  2009-01-06  california; part b; metro desk  news
#
#                  Tags Page is_economic      bert_sentiment
# 0  ratings & rankings  b.6           1  0.6987545491875828  ]
# Processing chunk 2:   0%|          | 0/1000 [00:00<?, ?it/s]
# [                                                Text WordCount       GOID  \
# 0  [more than 250 koi have been transported from ...       187  520563577
#
#            Publisher        Date                      Section  \
# 0  los angeles times  2010-06-26  home; part e; features desk
#
#                   Type   Tags Page is_economic      bert_sentiment
# 0  general information  ponds  e.4           1  0.5242249422136382  ,                                                 Text WordCount       GOID  \
# 0  [until miles austin's touchdown at the end of ...        57  410270518
#
#              Publisher        Date Section  Type  Tags  Page is_economic  \
# 0  washington post the  2008-09-29  sports  news  None  e.16           1
#
#         bert_sentiment
# 0  -0.9558036029338837  ]
# Processing chunk 3:   0%|          | 0/1000 [00:00<?, ?it/s]
# [                                                Text WordCount        GOID  \
# 0  [caitlynn mayhew filled the cardboard box with...       903  2453899647
#
#             Publisher        Date Section  Type  Tags  Page is_economic  \
# 0  usa today (online)  2020-10-24    news  news  food  None           1
#
#   bert_sentiment
# 0           None  ,                                                 Text WordCount       GOID  \
# 0  [remember that picture of elian gonzalez being...       560  409096715
#
#              Publisher        Date    Section  Type      Tags  Page  \
# 0  washington post the  2000-12-18  financial  news  startups  e.05
#
#   is_economic      bert_sentiment
# 0           1  -0.520898703891452  ]
#                                                 Text WordCount        GOID  \
# 0  [the legislature on thursday ratified agreemen...      1314   421304854
# 1  [carl pohlad, 93, the longtime owner of baseba...       283   422280280
# 2  [the supreme court unanimously shot down the n...       836   324720131
# 3  [nfl free agency started monday with a flurry ...      6104  2954767134
# 4  [local and state health officials are complain...       833   432879697
#
#              Publisher        Date                         Section  Type  \
# 0    los angeles times  1998-08-28              part-a; metro desk  news
# 1    los angeles times  2009-01-06  california; part b; metro desk  news
# 2  washington post the  2010-05-25                          sports  news
# 3   usa today (online)  2024-03-11                          sports  news
# 4       new york times  2004-10-22                               a  news
#
#                     Tags  Page is_economic        bert_sentiment
# 0                casinos     3           1  -0.44620480213120745
# 1     ratings & rankings   b.6           1    0.6987545491875828
# 2  professional baseball   d.1           1   -0.2690457679374204
# 3  professional football  None           1                  None
# 4           immunization  a.12           1                  None

# %%
data.head()
# Out:
#                                                 Text WordCount        GOID  \
# 0  [the legislature on thursday ratified agreemen...      1314   421304854
# 1  [carl pohlad, 93, the longtime owner of baseba...       283   422280280
# 2  [the supreme court unanimously shot down the n...       836   324720131
# 3  [nfl free agency started monday with a flurry ...      6104  2954767134
# 4  [local and state health officials are complain...       833   432879697
#
#              Publisher        Date                         Section  Type  \
# 0    los angeles times  1998-08-28              part-a; metro desk  news
# 1    los angeles times  2009-01-06  california; part b; metro desk  news
# 2  washington post the  2010-05-25                          sports  news
# 3   usa today (online)  2024-03-11                          sports  news
# 4       new york times  2004-10-22                               a  news
#
#                     Tags  Page is_economic        bert_sentiment
# 0                casinos     3           1  -0.44620480213120745
# 1     ratings & rankings   b.6           1    0.6987545491875828
# 2  professional baseball   d.1           1   -0.2690457679374204
# 3  professional football  None           1                  None
# 4           immunization  a.12           1                  None

# %%
from pathlib import Path

# Define the path to your stopwords file
project_path = Path('/home/ec2-user/SageMaker/david/tdm-sentiment/')
stopwords_path = 'code/nltk_data/corpora/english'

# Function to load stopwords
def load_stopwords(base_path, relative_path):
    file_path = base_path / relative_path
    if file_path.exists():
        return set(file_path.read_text().splitlines())
    else:
        raise FileNotFoundError(f"Stopwords file not found at {file_path}")

# Load the stopwords
stop_words = load_stopwords(project_path, stopwords_path)
# Out:
#                                                 Text  \
# 0  [the legislature on thursday ratified agreemen...
# 1  [carl pohlad, 93, the longtime owner of baseba...
# 2  [the supreme court unanimously shot down the n...
# 3  [nfl free agency started monday with a flurry ...
# 4  [local and state health officials are complain...
#
#                                            processed
# 0  legislature thursday ratified agreements struc...
# 1  carl longtime owner minnesota twins one wealth...
# 2  supreme court unanimously shot longtime quest ...
# 3  nfl free agency started monday flurry deals ev...
# 4  local state health officials complaining feder...

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Create the DTM
vectorizer = CountVectorizer(max_df=0.95, min_df=2, stop_words='english')
dtm = vectorizer.fit_transform(data['processed'])
vocab = vectorizer.get_feature_names_out()

print("Vocabulary size:", len(vocab))
print("Sample vocabulary:", vocab[:10])
# Out:
# Vocabulary size: 22913
# Sample vocabulary: ['aa' 'aaa' 'aac' 'aapi' 'aaron' 'aarp' 'ab' 'aba' 'aback' 'abandon']

# %%
from sklearn.decomposition import LatentDirichletAllocation

# Train the LDA model
lda = LatentDirichletAllocation(n_components=5, random_state=0)  # Adjust 'n_components' for the number of topics
lda.fit(dtm)

# Display the topics
for idx, topic in enumerate(lda.components_):
    print(f"Topic {idx}: {[vocab[i] for i in topic.argsort()[-10:]]}")
# Out:
# Topic 0: ['public', 'federal', 'officials', 'tax', 'people', 'health', 'city', 'new', 'state', 'said']
# Topic 1: ['billion', 'stock', 'year', 'companies', 'market', 'new', 'million', 'company', 'percent', 'said']
# Topic 2: ['want', 'says', 'use', 'time', 'make', 'company', 'people', 'like', 'said', 'new']
# Topic 3: ['according', 'department', 'president', 'state', 'government', 'court', 'officials', 'federal', 'new', 'said']
# Topic 4: ['chicago', 'theft', 'los', 'homes', 'said', 'new', 'home', 'stolen', 'june', 'property']

# %%
import nltk
from pathlib import Path

# Define the path to your stopwords file
project_path = Path('/home/ec2-user/SageMaker/david/tdm-sentiment/')
nltk_data = 'code/nltk_data/'


# Specify the local nltk_data path
nltk.data.path.append(project_path/ stopwords_path)

# %%
from nltk.corpus import wordnet

# Test WordNet access
synonyms = wordnet.synsets('run')
print("Synonyms for 'run':", [syn.lemma_names() for syn in synonyms[:5]])
from nltk.stem import WordNetLemmatizer

# Initialize the lemmatizer
lemmatizer = WordNetLemmatizer()
stopwords_path = 'code/nltk_data/corpora/english'

# Function to load stopwords
def load_stopwords(base_path, relative_path):
    file_path = base_path / relative_path
    if file_path.exists():
        return set(file_path.read_text().splitlines())
    else:
        raise FileNotFoundError(f"Stopwords file not found at {file_path}")

# Load the stopwords
stop_words = load_stopwords(project_path, stopwords_path)
print(stop_words)
# Out:
# Synonyms for 'run': [['run', 'tally'], ['test', 'trial', 'run'], ['footrace', 'foot_race', 'run'], ['streak', 'run'], ['run', 'running', 'running_play', 'running_game']]
# {'themselves', 'me', 'once', 'any', 've', 'has', 'don', "mustn't", 'her', 'that', 'between', 'through', 'be', 'so', 'out', 'very', 'it', 'again', 'during', 'when', 'they', "it's", 'hers', 'am', 'for', 'then', 'before', 'your', 'while', "doesn't", 'now', "hasn't", 's', 'up', "hadn't", 'have', 'hasn', 'until', 'doesn', 'after', 'aarp ', 'because', 'each', 'm', 'should', 'at', 'those', "needn't", 'aba ', 'some', "you're", 'been', 'more', 'our', 'theirs', 'down', 'he', 'him', 'shan', "that'll", 'will', 'by', "didn't", 'mightn', "don't", 'its', 'here', "haven't", "isn't", 'aa ', 'aac ', 'same', 'where', 'into', 'being', "couldn't", "you'd", 'nor', 'isn', 'we', 'hadn', 'she', "wasn't", 'how', 'aapi ', 'them', 'couldn', 'd', 'aback', 'i', 'with', 'didn', 'wasn', 'against', 'his', 'few', 'y', 'off', 'myself', 'all', 'of', 'who', 'having', 'there', 'both', "mightn't", 'shouldn', 'do', 'just', "should've", 'their', 'on', 'aaa ', 'as', 'is', 'in', 'and', 'll', 'aaron ', "you'll", 're', 'these', 'to', 'are', "won't", 'below', 'under', 'over', 'above', "wouldn't", 'aren', 'yours', 'was', 't', 'if', 'such', 'weren', 'himself', 'most', 'not', 'yourselves', 'won', 'but', 'o', 'why', 'wouldn', 'had', 'or', 'ourselves', 'whom', 'from', 'further', 'needn', 'a', 'my', "you've", 'own', 'ours', 'herself', "weren't", 'than', 'mustn', "she's", "shouldn't", 'were', 'other', 'the', 'ain', "aren't", 'this', 'an', 'does', 'doing', 'did', 'about', 'ab ', 'itself', 'yourself', 'only', 'too', "shan't", 'which', 'you', 'ma', 'can', 'no', 'what', 'haven'}

# %%
from nltk.stem import WordNetLemmatizer

# Initialize the lemmatizer
lemmatizer = WordNetLemmatizer()

from pathlib import Path

# Define the path to your stopwords file
project_path = Path('/home/ec2-user/SageMaker/david/tdm-sentiment/')
stopwords_path = 'code/nltk_data/corpora/english'

# Function to load stopwords
def load_stopwords(base_path, relative_path):
    file_path = base_path / relative_path
    if file_path.exists():
        return set(file_path.read_text().splitlines())
    else:
        raise FileNotFoundError(f"Stopwords file not found at {file_path}")

# Load the stopwords
stop_words = load_stopwords(project_path, stopwords_path)

# Define the preprocessing function with lemmatization
def preprocess_text_with_lemmatization(text_list, stop_words):
    if isinstance(text_list, list):
        text = ' '.join(text_list)
    else:
        return ''
    
    text = text.lower()
    tokens = text.split()
    tokens = [
        lemmatizer.lemmatize(word) 
        for word in tokens if word.isalpha() and word not in stop_words
    ]
    return ' '.join(tokens)


data['processed'] = data['Text'].apply(lambda x: preprocess_text_with_lemmatization(x, stop_words))
print(data[['Text', 'processed']].head())
# Out:
#                                                 Text  \
# 0  [the legislature on thursday ratified agreemen...
# 1  [carl pohlad, 93, the longtime owner of baseba...
# 2  [the supreme court unanimously shot down the n...
# 3  [nfl free agency started monday with a flurry ...
# 4  [local and state health officials are complain...
#
#                                            processed
# 0  legislature thursday ratified agreement struck...
# 1  carl longtime owner minnesota twin one wealthi...
# 2  supreme court unanimously shot longtime quest ...
# 3  nfl free agency started monday flurry deal eve...
# 4  local state health official complaining federa...

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Create the DTM
vectorizer = CountVectorizer(max_df=0.95, min_df=2, stop_words='english')
dtm = vectorizer.fit_transform(data['processed'])
vocab = vectorizer.get_feature_names_out()

print("Vocabulary size:", len(vocab))
print("Sample vocabulary:", vocab[:20])
# Out:
# Vocabulary size: 20116
# Sample vocabulary: ['aa' 'aaa' 'aac' 'aapi' 'aaron' 'aarp' 'ab' 'aba' 'abandon' 'abandoned'
#  'abandoning' 'abated' 'abatement' 'abbas' 'abbey' 'abbot' 'abbott'
#  'abbreviated' 'abby' 'abc']

# %%
from sklearn.decomposition import LatentDirichletAllocation

# Train the LDA model
lda = LatentDirichletAllocation(n_components=5, random_state=0)  # Adjust 'n_components' for the number of topics
lda.fit(dtm)

# Display the topics
for idx, topic in enumerate(lda.components_):
    print(f"Topic {idx}: {[vocab[i] for i in topic.argsort()[-10:]]}")
# Out:
# Topic 0: ['airline', 'village', 'home', 'theft', 'said', 'building', 'new', 'stolen', 'june', 'property']
# Topic 1: ['year', 'law', 'official', 'government', 'people', 'health', 'new', 'federal', 'state', 'said']
# Topic 2: ['people', 'water', 'car', 'year', 'million', 'company', 'official', 'new', 'city', 'said']
# Topic 3: ['stock', 'business', 'home', 'market', 'price', 'year', 'percent', 'new', 'said', 'company']
# Topic 4: ['game', 'million', 'board', 'year', 'time', 'team', 'student', 'new', 'school', 'said']

# %%
# Get the topic distribution for each document
topic_distribution = lda.transform(dtm)

# Assign the most probable topic to each document
data['topic'] = topic_distribution.argmax(axis=1)

print(data[['Text', 'processed', 'topic']].head())
# Out:
#                                                 Text  \
# 0  [the legislature on thursday ratified agreemen...
# 1  [carl pohlad, 93, the longtime owner of baseba...
# 2  [the supreme court unanimously shot down the n...
# 3  [nfl free agency started monday with a flurry ...
# 4  [local and state health officials are complain...
#
#                                            processed  topic
# 0  legislature thursday ratified agreement struck...      1
# 1  carl longtime owner minnesota twin one wealthi...      4
# 2  supreme court unanimously shot longtime quest ...      4
# 3  nfl free agency started monday flurry deal eve...      4
# 4  local state health official complaining federa...      1

# %%
import pandas as pd
import numpy as np
import re
import string
import nltk
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# Download necessary NLTK data files (only needed once)
#from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

def preprocess_text(text):
    """
    Preprocess the input text by:
    - Lowercasing
    - Removing punctuation and numbers
    - Tokenizing
    - Removing stopwords
    - Lemmatizing
    """
    # Initialize lemmatizer and stopwords
    lemmatizer = WordNetLemmatizer()
    
    # Lowercase the text
    text = text.lower()
    
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    
    # Remove numbers
    text = re.sub(r'\d+', '', text)
    
    # Tokenize the text
    tokens = text.split()
    
    # Remove stopwords and lemmatize
    tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words]
    
    # Join tokens back to string
    return ' '.join(tokens)

def perform_lda(df, text_column='Text', n_topics=5, max_iter=10, random_state=42):
    """
    Perform LDA on the specified text column of the DataFrame.
    
    Parameters:
        df (pd.DataFrame): DataFrame containing the text data.
        text_column (str): Name of the column containing text data.
        n_topics (int): Number of topics to extract.
        max_iter (int): Maximum number of iterations for the LDA algorithm.
        random_state (int): Random state for reproducibility.
        
    Returns:
        lda_model: Trained LDA model.
        vectorizer: CountVectorizer fitted on the text data.
        topic_words: List of words for each topic.
        df: DataFrame with an additional 'Topic' column.
    """
    # Check if text_column exists
    if text_column not in df.columns:
        raise ValueError(f"Column '{text_column}' not found in the DataFrame.")
    
    # Preprocess the text data
    print("Preprocessing text data...")
    df['processed_text'] = df[text_column].astype(str).apply(preprocess_text)
    
    # Create a document-term matrix
    print("Creating document-term matrix...")
    vectorizer = CountVectorizer(max_df=0.95, min_df=2, stop_words='english')
    dtm = vectorizer.fit_transform(df['processed_text'])
    
    # Check if DTM is empty
    if dtm.shape[1] == 0:
        raise ValueError("The document-term matrix is empty. Adjust 'max_df' and 'min_df' parameters.")
    
    # Fit the LDA model
    print("Fitting LDA model...")
    lda = LatentDirichletAllocation(n_components=n_topics, max_iter=max_iter,
                                    random_state=random_state, learning_method='batch')
    lda.fit(dtm)
    
    # Display the topics
    print(f"\nTop words per topic (n={n_topics}):")
    feature_names = vectorizer.get_feature_names_out()
    topic_words = []
    for topic_idx, topic in enumerate(lda.components_):
        top_indices = topic.argsort()[:-11:-1]  # Top 10 words
        top_words = [feature_names[i] for i in top_indices]
        topic_words.append(top_words)
        print(f"Topic {topic_idx +1}: " + ", ".join(top_words))
    
    # Assign topics to documents
    print("\nAssigning topics to documents...")
    doc_topic_dist = lda.transform(dtm)
    df['Topic'] = doc_topic_dist.argmax(axis=1) +1  # Adding 1 for readability
    
    return lda, vectorizer, topic_words, df, doc_topic_dist

def plot_top_words_per_topic(lda_model, vectorizer, n_top_words=10):
    """
    Plot the top words for each topic as a bar chart.
    
    Parameters:
        lda_model: Trained LDA model.
        vectorizer: Fitted CountVectorizer.
        n_top_words (int): Number of top words to display per topic.
    """
    feature_names = vectorizer.get_feature_names_out()
    n_topics = lda_model.n_components
    fig, axes = plt.subplots(1, n_topics, figsize=(20, 5), sharex=True)
    
    if n_topics ==1:
        axes = [axes]
    
    for topic_idx, ax in enumerate(axes):
        top_indices = lda_model.components_[topic_idx].argsort()[:-n_top_words -1:-1]
        top_words = [feature_names[i] for i in top_indices]
        top_weights = lda_model.components_[topic_idx][top_indices]
        
        ax.barh(top_words[::-1], top_weights[::-1], color='skyblue')
        ax.set_title(f"Topic {topic_idx +1}", fontdict={'fontsize': 15})
        ax.invert_yaxis()
        ax.tick_params(axis='both', which='major', labelsize=12)
    
    plt.tight_layout()
    plt.show()

def plot_wordclouds(topic_words):
    """
    Generate and display word clouds for each topic.
    
    Parameters:
        topic_words (list of lists): List containing lists of top words per topic.
    """
    n_topics = len(topic_words)
    fig, axes = plt.subplots(1, n_topics, figsize=(20, 5))
    
    if n_topics ==1:
        axes = [axes]
    
    for idx, (words, ax) in enumerate(zip(topic_words, axes)):
        # Assign weights based on word position (optional)
        # Here, all words have the same weight for simplicity
        word_freq = {word: 1 for word in words}
        wordcloud = WordCloud(width=400, height=200, background_color='white').generate_from_frequencies(word_freq)
        ax.imshow(wordcloud, interpolation='bilinear')
        ax.set_title(f"Topic {idx +1}", fontsize=15)
        ax.axis('off')
    
    plt.tight_layout()
    plt.show()

def plot_topic_distribution(doc_topic_dist, n_topics=5):
    """
    Plot a heatmap showing the distribution of topics across documents.
    
    Parameters:
        doc_topic_dist (numpy.ndarray): Array containing topic distributions for each document.
        n_topics (int): Number of topics.
    """
    # Create a DataFrame for the heatmap
    topic_columns = [f"Topic {i+1}" for i in range(n_topics)]
    df_topic_dist = pd.DataFrame(doc_topic_dist, columns=topic_columns)
    
    plt.figure(figsize=(12, 8))
    sns.heatmap(df_topic_dist, cmap='Blues', cbar=True)
    plt.title('Topic Distribution Across Documents', fontsize=16)
    plt.xlabel('Topics', fontsize=14)
    plt.ylabel('Documents', fontsize=14)
    plt.show()

def main():
    df = pd.DataFrame(data)
    
    # Perform LDA
    lda_model, vectorizer, topics, df_with_topics, doc_topic_dist = perform_lda(
        df, text_column='Text', n_topics=3, max_iter=100, random_state=42
    )
    
    # Display the DataFrame with assigned topics
    print("\nDataFrame with assigned topics:")
    print(df_with_topics)
    
    # Visualization 1: Bar Charts of Top Words per Topic
    plot_top_words_per_topic(lda_model, vectorizer, n_top_words=10)
    
    # Visualization 2: Word Clouds for Each Topic
    plot_wordclouds(topics)
    
    # Visualization 3: Topic Distribution Across Documents
    plot_topic_distribution(doc_topic_dist, n_topics=lda_model.n_components)

if __name__ == "__main__":
    main()
# Out:
# Preprocessing text data...
# Creating document-term matrix...
# Fitting LDA model...
#
# Top words per topic (n=3):
# Topic 1: said, year, state, company, new, million, percent, people, government, say
# Topic 2: said, year, company, new, time, like, say, million, photo, make
# Topic 3: said, block, city, dr, pm, vehicle, property, aug, area, rd
#
# Assigning topics to documents...
#
# DataFrame with assigned topics:
#                                                    Text WordCount        GOID  \
# 0     [the legislature on thursday ratified agreemen...      1314   421304854
# 1     [carl pohlad, 93, the longtime owner of baseba...       283   422280280
# 2     [the supreme court unanimously shot down the n...       836   324720131
# 3     [nfl free agency started monday with a flurry ...      6104  2954767134
# 4     [local and state health officials are complain...       833   432879697
# ...                                                 ...       ...         ...
# 2995  [top 5., five top gamecube titles to check out...        76   420157128
# 2996  [raymond e. figlewicz, age 52, of plymouth, mi...        86   420087763
# 2997  [after a week of triumph and tragedy, 670 cycl...       638   421712806
# 2998  [kay watson presented at play with this challe...       398   420370780
# 2999  [legendary jeweler c.d. peacock returns to mic...       727   419095941
#
#                 Publisher        Date                         Section  Type  \
# 0       los angeles times  1998-08-28              part-a; metro desk  news
# 1       los angeles times  2009-01-06  california; part b; metro desk  news
# 2     washington post the  2010-05-25                          sports  news
# 3      usa today (online)  2024-03-11                          sports  news
# 4          new york times  2004-10-22                               a  news
# ...                   ...         ...                             ...   ...
# 2995      chicago tribune  2004-04-22                           tempo  news
# 2996      chicago tribune  2003-09-23                      obituaries  news
# 2997    los angeles times  2002-05-20          california; metro desk  news
# 2998      chicago tribune  2005-12-29                         at play  news
# 2999      chicago tribune  2000-06-05                        business  news
#
#                        Tags  Page is_economic        bert_sentiment  \
# 0                   casinos     3           1  -0.44620480213120745
# 1        ratings & rankings   b.6           1    0.6987545491875828
# 2     professional baseball   d.1           1   -0.2690457679374204
# 3     professional football  None           1                  None
# 4              immunization  a.12           1                  None
# ...                     ...   ...         ...                   ...
# 2995                   None     5           1                  None
# 2996                   None     6           1     0.853927493095398
# 2997           fund raising   b.3           1   0.23424557760040016
# 2998                   None     2           1    0.8685734454854076
# 2999                   None     3           1   0.08028367547357572
#
#                                               processed  \
# 0     legislature thursday ratified agreement struck...
# 1     carl longtime owner minnesota twin one wealthi...
# 2     supreme court unanimously shot longtime quest ...
# 3     nfl free agency started monday flurry deal eve...
# 4     local state health official complaining federa...
# ...                                                 ...
# 2995  top five top gamecube title check selected edi...
# 2996  raymond age died suddenly september born raise...
# 2997  week triumph cyclist rode los angeles ending t...
# 2998  kay watson presented play find restaurant conf...
# 2999  legendary jeweler peacock return michigan aven...
#
#                                          processed_text  Topic
# 0     legislature thursday ratified agreement struck...      1
# 1     carl pohlad longtime owner baseball minnesota ...      2
# 2     supreme court unanimously shot nfls longtime q...      1
# 3     nfl free agency started monday flurry deal – e...      2
# 4     local state health official complaining federa...      1
# ...                                                 ...    ...
# 2995  top five top gamecube title check april select...      2
# 2996  raymond e figlewicz age plymouth michigan died...      3
# 2997  week triumph tragedy cyclist rode los angeles ...      3
# 2998  kay watson presented play challenge find fun r...      2
# 2999  legendary jeweler cd peacock return michigan a...      2
#
# [3000 rows x 14 columns]
