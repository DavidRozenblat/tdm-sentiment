# %%
from pathlib import Path
import pandas as pd
from tqdm.notebook import tqdm
from joblib import Parallel, delayed
from copy import copy
import sys
import seaborn as sns
import matplotlib.pyplot as plt

# Add the 'code' directory to sys.path
project_path = Path(
    '/home/ec2-user/SageMaker/david/tdm-sentiment/'
)
data_path = project_path / 'data/'
data_sample = Path('/home/ec2-user/SageMaker/data/')
dataset_name = 'StartupSentiment' #TODO  # 'USATodayDavid' ChicagoTribune' 'Newyork20042023' TheWashingtonPostDavid, LosAngelesTimesDavid, StartupSentiment
folder_path = data_path / 'results/' / dataset_name #TODO

sys.path.append(str(project_path / 'code'))
from salience_index.salience_index import SalienceScorer
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
def get_all_csv_files(folder_path):
    # Use Path to find all CSV files in the folder
    csv_files = list(Path(folder_path).glob('*.csv'))
    return csv_files



def concat_csv_files(folder_path):
    # Get a list of all CSV files in the folder
    csv_files = get_all_csv_files(folder_path)
    
    # Initialize an empty list to store DataFrames
    df_list = []
    
    # Loop through the list of CSV files
    for file in csv_files:
        # Read each CSV file into a DataFrame
        df = pd.read_csv(file)
        
        # Append the DataFrame to the list
        df_list.append(df)
    
    # Concatenate all DataFrames in the list into a single DataFrame
    combined_df = pd.concat(df_list, ignore_index=True)
    
    return combined_df

    

def label_sentiment(sentiment_score):
    """
    Labels sentiment as 'positive', 'negative', or 'neutral' based on the sentiment score.
    
    Args:
        sentiment_score (float): The sentiment score ranging from -1 to 1.
        
    Returns:
        str: The sentiment label ('positive', 'negative', or 'neutral').
    """
    if sentiment_score > 0.5:
        return 'positive'
    elif sentiment_score < -0.5:
        return 'negative'
    else:
        return 'neutral'
 

# Define a function to compute salience score
def compute_salience(row):
    try:
        return scorer.get_salience_score(row['Date'], row['Page'], row['WordCount'], row['Publisher'])
    except Exception:
        return None

# %%
# Combine CSV files from all files
combined_df = concat_csv_files(folder_path)

# Drop duplicate rows based on the 'GOID' column
combined_df = combined_df.drop_duplicates(subset=['GOID'])

# Combine 'International Herald Tribune' and 'New York Times' into one category
combined_df['Publisher'] = combined_df['Publisher'].replace(
    {'international herald tribune': 'new york times',
     'new york times the': 'new york times',
     'international new york times': 'new york times',
     'los angeles times (pre-1997 fulltext)': 'los angeles times',
     'washington post (pre-1997 fulltext) the': 'washington post the',
     'usa today (online)': 'usa today'}
)


combined_df = combined_df[combined_df['Publisher'] != 'new york times español']

#combined_df
#combined_df = combined_df[combined_df['Sentiment_Label'] != 'neutral']


#combined_df = combined_df[combined_df['Publisher'] == 'new york times']

combined_df = combined_df[combined_df[['bert_sentiment', 'Page']].notna().all(axis=1)]
#combined_df = combined_df[combined_df['Date'].dt.year > 2023]

# Initialize the scorer
scorer = SalienceScorer()

# Apply the function to each row
combined_df['salience_score'] = combined_df.apply(compute_salience, axis=1)
combined_df['adjusted_sentiment'] = combined_df['bert_sentiment']*combined_df['salience_score']

# Normalizing 'bert_sentiment' and 'adjusted_sentiment' columns to a range of -1 to 1
#combined_df['bert_sentiment'] = 2 * ((combined_df['bert_sentiment'] - combined_df['bert_sentiment'].min()) / (combined_df['bert_sentiment'].max() - combined_df['bert_sentiment'].min())) - 1
#combined_df['adjusted_sentiment'] = 2 * ((combined_df['adjusted_sentiment'] - combined_df['adjusted_sentiment'].min()) / (combined_df['adjusted_sentiment'].max() - combined_df['adjusted_sentiment'].min())) - 1

#Normalizing 'bert_sentiment' and 'adjusted_sentiment'
# Normalizing 'bert_sentiment' and 'adjusted_sentiment'
combined_df['bert_sentiment'] = (
    (combined_df['bert_sentiment'] - combined_df['bert_sentiment'].mean()) / combined_df['bert_sentiment'].std()
)

combined_df['adjusted_sentiment'] = (
    (combined_df['adjusted_sentiment'] - combined_df['adjusted_sentiment'].mean()) / combined_df['adjusted_sentiment'].std()
)

# scale up 
combined_df['adjusted_sentiment'] = combined_df['adjusted_sentiment']#*10
#combined_df['adjusted_sentiment_normalized'] = combined_df['adjusted_sentiment_normalized']#*10

#combined_df = combined_df[combined_df['Publisher'] == 'usa today']

combined_df['bert_sentiment_label'] = combined_df['bert_sentiment'].apply(label_sentiment)
combined_df['adjusted_sentiment_label'] = combined_df['adjusted_sentiment'].apply(label_sentiment)
# Out:
# Unknown dataset name: atlanta journal the atlanta constitution (pre-1997 fulltext) the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: south florida sun - sentinel
# Unknown dataset name: vancouver sun the
# Unknown dataset name: jerusalem post
# Unknown dataset name: australian financial review the
# Unknown dataset name: pittsburgh post - gazette
# Unknown dataset name: lincoln journal star
# Unknown dataset name: jerusalem post
# Unknown dataset name: national post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jewish exponent
# Unknown dataset name: newsday
# Unknown dataset name: times - news
# Unknown dataset name: boston globe (pre-1997 fulltext)
# Unknown dataset name: gazette the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jewish exponent
# Unknown dataset name: corpus christi caller - times
# Unknown dataset name: jerusalem post
# Unknown dataset name: scotsman the
# Unknown dataset name: jewish advocate
# Unknown dataset name: rochester democrat and chronicle
# Unknown dataset name: toronto star
# Unknown dataset name: record the
# Unknown dataset name: jerusalem post
# Unknown dataset name: waterloo region record
# Unknown dataset name: age the
# Unknown dataset name: daily herald
# Unknown dataset name: jerusalem post
# Unknown dataset name: boston globe
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: pittsburgh post - gazette
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: kingston whig - standard
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: daily telegraph the
# Unknown dataset name: temps  le
# Unknown dataset name: national post
# Unknown dataset name: canberra times the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: australian the
# Unknown dataset name: calgary herald
# Unknown dataset name: journal news the
# Unknown dataset name: ottawa citizen the
# Unknown dataset name: sudbury star
# Unknown dataset name: south florida sun - sentinel
# Unknown dataset name: australian the
# Unknown dataset name: jerusalem post
# Unknown dataset name: orlando sentinel
# Unknown dataset name: jerusalem post
# Unknown dataset name: jewish advocate
# Unknown dataset name: boston globe
# Unknown dataset name: baltimore sun the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: boston globe
# Unknown dataset name: bismarck tribune
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: salt lake tribune the
# Unknown dataset name: age the
# Unknown dataset name: calgary herald
# Unknown dataset name: jerusalem post
# Unknown dataset name: weekend australian
# Unknown dataset name: jerusalem post
# Unknown dataset name: monde  le
# Unknown dataset name: jerusalem post
# Unknown dataset name: orlando sentinel
# Unknown dataset name: northern advocate the
# Unknown dataset name: toronto star
# Unknown dataset name: globe and mail the
# Unknown dataset name: vancouver sun the
# Unknown dataset name: nanaimo daily news
# Unknown dataset name: jerusalem post
# Unknown dataset name: philadelphia tribune
# Unknown dataset name: daily mail
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: new york daily news
# Unknown dataset name: prensa san diego  la
# Unknown dataset name: toronto star
# Unknown dataset name: pretoria news the
# Unknown dataset name: intelligencer the
# Unknown dataset name: middle east news online
# Unknown dataset name: globe and mail the
# Unknown dataset name: jerusalem post
# Unknown dataset name: star tribune
# Unknown dataset name: jerusalem post
# Unknown dataset name: australian financial review the
# Unknown dataset name: jerusalem post
# Unknown dataset name: press democrat the
# Unknown dataset name: news journal, the
# Unknown dataset name: star tribune
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: newsday
# Unknown dataset name: australian the
# Unknown dataset name: boston globe
# Unknown dataset name: jerusalem post
# Unknown dataset name: daily telegraph the
# Unknown dataset name: australian the
# Unknown dataset name: american israelite the
# Unknown dataset name: jerusalem post
# Unknown dataset name: globe and mail the
# Unknown dataset name: jerusalem post
# Unknown dataset name: hartford courant
# Unknown dataset name: boston globe
# Unknown dataset name: irish times
# Unknown dataset name: australian financial review the
# Unknown dataset name: jerusalem post
# Unknown dataset name: commercial appeal the
# Unknown dataset name: forward
# Unknown dataset name: southland times the
# Unknown dataset name: orlando sentinel
# Unknown dataset name: coventry telegraph
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: philadelphia inquirer
# Unknown dataset name: poughkeepsie journal the
# Unknown dataset name: new zealand herald the
# Unknown dataset name: journal news the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: evansville courier & press
# Normalization failed for page tag: a014
# Unknown dataset name: weekend australian
# Unknown dataset name: globe and mail the
# Unknown dataset name: ottawa citizen the
# Unknown dataset name: south florida sun - sentinel
# Unknown dataset name: sydney morning herald
# Unknown dataset name: jerusalem post
# Unknown dataset name: daily breeze
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: post and courier the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: newsday
# Unknown dataset name: china daily
# Unknown dataset name: star tribune
# Unknown dataset name: jerusalem post
# Unknown dataset name: new straits times
# Unknown dataset name: australian the
# Unknown dataset name: daily express
# Unknown dataset name: star tribune
# Unknown dataset name: daily record
# Unknown dataset name: pittsburgh post - gazette
# Unknown dataset name: citizen the
# Unknown dataset name: indianapolis star
# Unknown dataset name: leader post
# Unknown dataset name: sowetan
# Unknown dataset name: daily telegraph the
# Unknown dataset name: daily post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: newsday
# Unknown dataset name: newsday
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: vancouver sun the
# Unknown dataset name: canberra times the
# Unknown dataset name: green bay press gazette
# Unknown dataset name: waterloo region record
# Unknown dataset name: vancouver sun the
# Unknown dataset name: guelph mercury the
# Unknown dataset name: star tribune
# Unknown dataset name: evening standard
# Unknown dataset name: toronto star
# Unknown dataset name: guardian the
# Unknown dataset name: jerusalem post
# Unknown dataset name: globe and mail the
# Unknown dataset name: boston globe (pre-1997 fulltext)
# Unknown dataset name: sunday age
# Unknown dataset name: sydney morning herald
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: birmingham post
# Unknown dataset name: ottawa citizen the
# Unknown dataset name: independent the
# Unknown dataset name: sydney morning herald
# Unknown dataset name: reforma
# Unknown dataset name: age the
# Unknown dataset name: jerusalem post
# Unknown dataset name: times - colonist
# Unknown dataset name: deseret news
# Unknown dataset name: wisconsin state journal
# Unknown dataset name: boston globe
# Unknown dataset name: jewish advocate
# Unknown dataset name: sydney morning herald
# Unknown dataset name: niagara falls review
# Unknown dataset name: daily sentinel review the
# Unknown dataset name: news journal, the
# Unknown dataset name: morning call
# Normalization failed for page tag: a11
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: atlanta journal the atlanta constitution the
# Unknown dataset name: australian financial review the
# Unknown dataset name: forward
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: national post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: mail on sunday
# Unknown dataset name: jewish exponent
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: pittsburgh post - gazette
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: baltimore sun the
# Unknown dataset name: globe and mail the
# Unknown dataset name: australian the
# Unknown dataset name: irish times
# Unknown dataset name: journal record
# Unknown dataset name: daily mail
# Unknown dataset name: sunday mirror
# Unknown dataset name: orlando sentinel
# Unknown dataset name: national post
# Unknown dataset name: commercial appeal the
# Unknown dataset name: toronto star
# Unknown dataset name: edmonton journal
# Unknown dataset name: edmonton journal
# Unknown dataset name: jerusalem post
# Unknown dataset name: ottawa citizen the
# Unknown dataset name: boston globe
# Unknown dataset name: detroit free press
# Unknown dataset name: tampa bay times
# Unknown dataset name: forward
# Unknown dataset name: guardian the
# Unknown dataset name: press and journal the
# Unknown dataset name: vancouver sun the
# Unknown dataset name: daily record the
# Unknown dataset name: milwaukee journal sentinel
# Unknown dataset name: western morning news the
# Unknown dataset name: jerusalem post
# Unknown dataset name: corpus christi caller - times
# Unknown dataset name: boston globe
# Unknown dataset name: forward
# Unknown dataset name: indianapolis star
# Unknown dataset name: glasgow times
# Unknown dataset name: tampa bay times
# Unknown dataset name: reforma
# Unknown dataset name: chicago tribune (pre-1997 fulltext)
# Unknown dataset name: courier - mail the
# Unknown dataset name: jerusalem post
# Unknown dataset name: forward
# Unknown dataset name: record the
# Unknown dataset name: age the
# Unknown dataset name: jewish exponent
# Normalization failed for page tag: a30
# Normalization failed for page tag: cs.01.f
# Unknown dataset name: newsday
# Unknown dataset name: green bay press gazette
# Unknown dataset name: australian the
# Unknown dataset name: christian science monitor, the
# Unknown dataset name: journal
# Unknown dataset name: jerusalem post
# Unknown dataset name: boston globe
# Unknown dataset name: jewish exponent
# Unknown dataset name: jerusalem post
# Unknown dataset name: daily record
# Unknown dataset name: jackson sun the
# Unknown dataset name: jerusalem post
# Unknown dataset name: toronto star
# Unknown dataset name: national post
# Unknown dataset name: china daily
# Unknown dataset name: times - colonist
# Unknown dataset name: jerusalem post
# Unknown dataset name: springfield news leader
# Unknown dataset name: globe and mail the
# Unknown dataset name: usa today (pre-1997 fulltext)
# Unknown dataset name: globe and mail the
# Unknown dataset name: chicago tribune (pre-1997 fulltext)
# Unknown dataset name: edmonton journal
# Unknown dataset name: village voice the
# Unknown dataset name: jerusalem post
# Unknown dataset name: globe and mail the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: scotsman the
# Unknown dataset name: jerusalem post
# Normalization failed for page tag: fp.1.fr
# Unknown dataset name: press the
# Unknown dataset name: jerusalem post
# Unknown dataset name: monde  le
# Unknown dataset name: weekend australian
# Unknown dataset name: jerusalem post
# Unknown dataset name: south florida sun - sentinel
# Unknown dataset name: news journal, the
# Unknown dataset name: globe and mail the
# Unknown dataset name: leader post
# Unknown dataset name: jerusalem post
# Unknown dataset name: detroit free press
# Unknown dataset name: sydney morning herald
# Unknown dataset name: national post
# Unknown dataset name: jerusalem post
# Unknown dataset name: expositor
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: star tribune
# Unknown dataset name: vancouver sun the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: evening standard
# Unknown dataset name: hartford courant
# Unknown dataset name: jerusalem post
# Unknown dataset name: australian the
# Unknown dataset name: jerusalem post
# Unknown dataset name: hartford courant
# Unknown dataset name: australian the
# Unknown dataset name: chicago tribune (pre-1997 fulltext)
# Unknown dataset name: gazette the
# Unknown dataset name: australian the
# Unknown dataset name: jerusalem post
# Unknown dataset name: evening sun the
# Unknown dataset name: jerusalem post
# Unknown dataset name: daily herald
# Unknown dataset name: gazette the
# Unknown dataset name: bath chronicle the
# Unknown dataset name: guelph mercury the
# Unknown dataset name: post and courier the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: china daily
# Unknown dataset name: hartford courant
# Unknown dataset name: toronto star
# Unknown dataset name: christian science monitor, the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: dominion post
# Unknown dataset name: globe and mail the
# Unknown dataset name: daily news
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: south florida sun - sentinel
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: press the
# Unknown dataset name: jerusalem post
# Unknown dataset name: toronto star
# Unknown dataset name: china daily
# Unknown dataset name: jerusalem post
# Unknown dataset name: des moines register
# Unknown dataset name: jerusalem post
# Unknown dataset name: monde  le
# Unknown dataset name: daily mail
# Unknown dataset name: greenville news the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: national post
# Unknown dataset name: national post
# Unknown dataset name: stuart news the
# Unknown dataset name: christian science monitor, the
# Unknown dataset name: jerusalem post
# Unknown dataset name: ottawa citizen the
# Unknown dataset name: wanganui chronicle
# Unknown dataset name: canberra times the
# Unknown dataset name: independent on sunday the
# Unknown dataset name: australian financial review the
# Unknown dataset name: toronto star
# Unknown dataset name: national post
# Unknown dataset name: poughkeepsie journal the
# Unknown dataset name: chattanooga times free press
# Unknown dataset name: jerusalem post
# Normalization failed for page tag: f.1.fro
# Unknown dataset name: jerusalem post
# Unknown dataset name: irish times
# Unknown dataset name: norte  el
# Unknown dataset name: press & sun-bulletin
# Unknown dataset name: jerusalem post
# Unknown dataset name: china daily
# Unknown dataset name: philadelphia daily news
# Unknown dataset name: jerusalem post
# Unknown dataset name: western mail
# Unknown dataset name: greenville news the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: independent the
# Unknown dataset name: globe and mail the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: australian the
# Unknown dataset name: jerusalem post
# Unknown dataset name: globe and mail the
# Unknown dataset name: forward
# Unknown dataset name: australian the
# Unknown dataset name: sunday gazette - mail
# Unknown dataset name: hamilton news, mountain edition
# Unknown dataset name: jerusalem post
# Unknown dataset name: daily mail
# Unknown dataset name: jerusalem post
# Unknown dataset name: oakland tribune
# Unknown dataset name: jerusalem post
# Unknown dataset name: northern advocate the
# Unknown dataset name: guardian the
# Unknown dataset name: atlanta journal the atlanta constitution the
# Unknown dataset name: age the
# Unknown dataset name: jewish exponent
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: forward
# Unknown dataset name: jerusalem post
# Unknown dataset name: temps  le
# Unknown dataset name: jerusalem post
# Unknown dataset name: calgary herald
# Unknown dataset name: arizona daily star
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: australian the
# Unknown dataset name: jerusalem post
# Unknown dataset name: toronto star
# Unknown dataset name: south florida sun - sentinel
# Unknown dataset name: las vegas review - journal
# Unknown dataset name: jerusalem post
# Unknown dataset name: daily post
# Unknown dataset name: echos  les
# Unknown dataset name: afro - american red star
# Unknown dataset name: daily telegraph the
# Unknown dataset name: dayton daily news
# Unknown dataset name: southland times the
# Unknown dataset name: philadelphia inquirer
# Unknown dataset name: province the
# Unknown dataset name: jerusalem post
# Unknown dataset name: newsday
# Unknown dataset name: boston globe
# Unknown dataset name: newsday
# Unknown dataset name: wisconsin state journal
# Unknown dataset name: sydney morning herald
# Unknown dataset name: jerusalem post
# Unknown dataset name: arizona daily star
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: ottawa citizen the
# Unknown dataset name: record the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: northern advocate the
# Unknown dataset name: baltimore sun the
# Unknown dataset name: ithaca journal the
# Unknown dataset name: jerusalem post
# Unknown dataset name: echos  les
# Unknown dataset name: south florida sun - sentinel
# Unknown dataset name: cape times
# Unknown dataset name: jewish advocate
# Unknown dataset name: jerusalem post
# Unknown dataset name: vancouver sun the
# Unknown dataset name: jerusalem post
# Unknown dataset name: evening standard
# Unknown dataset name: jerusalem post
# Unknown dataset name: jewish advocate
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: windsor star the
# Unknown dataset name: herald on sunday
# Unknown dataset name: national post
# Unknown dataset name: daily telegraph the
# Unknown dataset name: advocate the
# Unknown dataset name: st. louis post - dispatch
# Unknown dataset name: jerusalem post
# Unknown dataset name: daily telegraph the
# Unknown dataset name: guardian the
# Unknown dataset name: jerusalem post
# Unknown dataset name: philadelphia daily news
# Unknown dataset name: times - transcript the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: winnipeg sun the
# Unknown dataset name: irish independent
# Unknown dataset name: guardian the
# Unknown dataset name: daily mirror the
# Unknown dataset name: sunday telegraph the
# Normalization failed for page tag: 0
# Unknown dataset name: jerusalem post
# Unknown dataset name: globe and mail the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Normalization failed for page tag: a.1.fro
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: daily mail
# Unknown dataset name: tennessean the
# Unknown dataset name: australian the
# Unknown dataset name: hartford courant
# Unknown dataset name: jerusalem post
# Unknown dataset name: daily herald-tribune the
# Unknown dataset name: daily telegraph the
# Unknown dataset name: globe and mail the
# Unknown dataset name: national post
# Unknown dataset name: winnipeg free press
# Unknown dataset name: jewish exponent
# Unknown dataset name: boston globe
# Unknown dataset name: corpus christi caller - times
# Unknown dataset name: jerusalem post
# Unknown dataset name: pantagraph
# Unknown dataset name: sunday telegraph the
# Unknown dataset name: sunday herald
# Unknown dataset name: jerusalem post
# Unknown dataset name: south florida sun - sentinel
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: boston globe
# Unknown dataset name: boston globe
# Unknown dataset name: ottawa citizen the
# Unknown dataset name: arizona republic
# Unknown dataset name: telegraph - herald
# Unknown dataset name: bay of plenty times
# Normalization failed for page tag: e.1.bre
# Unknown dataset name: baltimore sun the
# Unknown dataset name: south florida sun - sentinel
# Unknown dataset name: calgary herald
# Unknown dataset name: presse die
# Unknown dataset name: age the
# Unknown dataset name: pais  el
# Unknown dataset name: jerusalem post
# Unknown dataset name: age the
# Unknown dataset name: jerusalem post
# Unknown dataset name: daily telegraph the
# Unknown dataset name: national post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: st. louis post - dispatch
# Unknown dataset name: waterloo region record
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: toronto star
# Unknown dataset name: daily telegraph the
# Unknown dataset name: globe and mail the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: atlanta journal - constitution the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jewish exponent
# Unknown dataset name: philadelphia inquirer
# Unknown dataset name: hartford courant
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: arizona capitol times
# Normalization failed for page tag: a15
# Unknown dataset name: atlanta constitution the
# Unknown dataset name: jerusalem post
# Unknown dataset name: boston globe (pre-1997 fulltext)
# Unknown dataset name: vancouver sun the
# Unknown dataset name: jerusalem post
# Unknown dataset name: ottawa citizen the
# Unknown dataset name: times record news
# Unknown dataset name: jerusalem post
# Unknown dataset name: monde  le
# Unknown dataset name: australian the
# Unknown dataset name: courier - mail the
# Unknown dataset name: jerusalem post
# Unknown dataset name: newsday
# Unknown dataset name: orlando sentinel
# Unknown dataset name: winnipeg free press
# Unknown dataset name: jerusalem post
# Unknown dataset name: ottawa citizen the
# Unknown dataset name: dayton daily news
# Unknown dataset name: tampa bay times
# Unknown dataset name: age the
# Unknown dataset name: jerusalem post
# Unknown dataset name: toronto sun the
# Unknown dataset name: commercial appeal the
# Unknown dataset name: tampa bay times
# Unknown dataset name: winnipeg free press
# Unknown dataset name: national post
# Unknown dataset name: cape times
# Unknown dataset name: newsday
# Unknown dataset name: st. louis post - dispatch
# Unknown dataset name: jerusalem post
# Unknown dataset name: mercury news the
# Unknown dataset name: telegraph-journal
# Unknown dataset name: jerusalem post
# Unknown dataset name: china daily
# Unknown dataset name: southland times the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: globe and mail the
# Unknown dataset name: australian financial review the
# Unknown dataset name: toronto star
# Unknown dataset name: daily telegraph the
# Unknown dataset name: jerusalem post
# Unknown dataset name: san jose mercury news
# Unknown dataset name: commercial appeal the
# Unknown dataset name: daily times
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jewish advocate
# Unknown dataset name: new straits times
# Unknown dataset name: milwaukee journal sentinel
# Unknown dataset name: jerusalem post
# Unknown dataset name: observer
# Unknown dataset name: jewish advocate
# Unknown dataset name: jerusalem post
# Unknown dataset name: arizona republic
# Unknown dataset name: china daily
# Unknown dataset name: jerusalem post
# Unknown dataset name: salt lake tribune the
# Unknown dataset name: south florida sun - sentinel
# Unknown dataset name: jerusalem post
# Unknown dataset name: milwaukee journal sentinel
# Unknown dataset name: tampa bay times
# Unknown dataset name: jerusalem post
# Unknown dataset name: daily mail
# Unknown dataset name: jerusalem post
# Unknown dataset name: baltimore sun the
# Unknown dataset name: jerusalem post
# Unknown dataset name: national post
# Unknown dataset name: irish times
# Unknown dataset name: china daily
# Unknown dataset name: jerusalem post
# Unknown dataset name: globe and mail the
# Unknown dataset name: toronto star
# Unknown dataset name: monde  le
# Unknown dataset name: jerusalem post
# Unknown dataset name: forward
# Unknown dataset name: des moines register
# Unknown dataset name: jewish exponent
# Unknown dataset name: independent (daily edition) the
# Unknown dataset name: daily breeze
# Unknown dataset name: atlanta journal - constitution the
# Unknown dataset name: daily mirror the
# Unknown dataset name: jerusalem post
# Unknown dataset name: china daily
# Unknown dataset name: boston globe
# Unknown dataset name: arizona business gazette
# Unknown dataset name: star tribune
# Unknown dataset name: guardian the
# Unknown dataset name: herald times reporter
# Unknown dataset name: china daily
# Unknown dataset name: jerusalem post
# Unknown dataset name: toronto star
# Unknown dataset name: jewish exponent
# Unknown dataset name: chicago tribune (pre-1997 fulltext)
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: new york daily news
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: toronto star
# Unknown dataset name: jerusalem post
# Unknown dataset name: desert sun the
# Unknown dataset name: observer the
# Unknown dataset name: jerusalem post
# Unknown dataset name: mail on sunday
# Unknown dataset name: new york daily news
# Unknown dataset name: detroit free press
# Unknown dataset name: atlanta journal the
# Unknown dataset name: guardian the
# Unknown dataset name: courier - mail the
# Unknown dataset name: calgary herald
# Unknown dataset name: spokesman review
# Unknown dataset name: south florida sun - sentinel
# Unknown dataset name: jerusalem post
# Unknown dataset name: journal of commerce
# Unknown dataset name: jerusalem post
# Unknown dataset name: australian the
# Unknown dataset name: montgomery advertiser
# Unknown dataset name: mural
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: australian financial review the
# Unknown dataset name: times - colonist
# Unknown dataset name: jewish advocate
# Unknown dataset name: news letter
# Unknown dataset name: middle east news online
# Unknown dataset name: leader post
# Unknown dataset name: ottawa citizen the
# Unknown dataset name: boston globe
# Normalization failed for page tag: e003
# Unknown dataset name: herald sun
# Unknown dataset name: waterloo region record
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: vancouver sun the
# Unknown dataset name: independent the
# Unknown dataset name: independent the
# Unknown dataset name: globe and mail the
# Unknown dataset name: scotland on sunday
# Unknown dataset name: advertiser the
# Unknown dataset name: corpus christi caller - times
# Unknown dataset name: irish times
# Unknown dataset name: jerusalem post
# Unknown dataset name: toronto star
# Unknown dataset name: jerusalem post
# Unknown dataset name: echos  les
# Unknown dataset name: china daily
# Unknown dataset name: jerusalem post
# Unknown dataset name: chicago tribune (pre-1997 fulltext)
# Unknown dataset name: china daily
# Unknown dataset name: guardian the
# Unknown dataset name: des moines register
# Unknown dataset name: loughborough echo
# Unknown dataset name: newsday
# Unknown dataset name: times record news
# Unknown dataset name: daily news the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: evening standard
# Unknown dataset name: niagara falls review
# Unknown dataset name: independent (daily edition) the
# Unknown dataset name: australian the
# Unknown dataset name: jerusalem post
# Unknown dataset name: china daily
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: st. louis post - dispatch
# Unknown dataset name: philadelphia inquirer
# Unknown dataset name: jerusalem post
# Unknown dataset name: south florida sun - sentinel
# Unknown dataset name: independent the
# Unknown dataset name: sunday gazette - mail
# Unknown dataset name: jerusalem post
# Unknown dataset name: new zealand herald the
# Unknown dataset name: indianapolis star
# Unknown dataset name: daily graphic the
# Unknown dataset name: sudbury star
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: china daily
# Unknown dataset name: daily mail
# Unknown dataset name: edmonton journal
# Unknown dataset name: jerusalem post
# Unknown dataset name: gazette the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: ottawa citizen the
# Unknown dataset name: daily mail
# Unknown dataset name: cape argus
# Unknown dataset name: ottawa citizen the
# Unknown dataset name: baltimore sun the
# Unknown dataset name: star tribune
# Unknown dataset name: jerusalem post
# Unknown dataset name: calgary herald
# Unknown dataset name: ottawa citizen the
# Unknown dataset name: public opinion
# Unknown dataset name: baltimore sun the
# Unknown dataset name: south florida sun - sentinel
# Unknown dataset name: pittsburgh post - gazette
# Unknown dataset name: newsday
# Unknown dataset name: courier - news
# Unknown dataset name: daily mail
# Unknown dataset name: telegram & gazette
# Unknown dataset name: jerusalem post
# Unknown dataset name: salt lake tribune the
# Unknown dataset name: register - guard the
# Unknown dataset name: mural
# Unknown dataset name: australian financial review the
# Unknown dataset name: nanaimo daily news
# Unknown dataset name: jerusalem post
# Unknown dataset name: waterloo region record
# Unknown dataset name: anderson independent mail
# Unknown dataset name: jerusalem post
# Unknown dataset name: reno gazette - journal
# Unknown dataset name: green bay press gazette
# Unknown dataset name: bath chronicle the
# Unknown dataset name: ottawa citizen the
# Unknown dataset name: san francisco examiner
# Unknown dataset name: times recorder
# Unknown dataset name: jerusalem post
# Unknown dataset name: newsday
# Unknown dataset name: tennessean the
# Unknown dataset name: jerusalem post
# Unknown dataset name: australian the
# Unknown dataset name: jewish exponent
# Unknown dataset name: boston globe (pre-1997 fulltext)
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jewish exponent
# Unknown dataset name: newsday
# Unknown dataset name: anderson independent mail
# Unknown dataset name: jewish exponent
# Unknown dataset name: jerusalem post
# Unknown dataset name: guardian the
# Unknown dataset name: business day
# Unknown dataset name: australian financial review the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jewish exponent
# Unknown dataset name: birmingham post
# Unknown dataset name: daily mail
# Unknown dataset name: toronto sun the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: guardian the
# Unknown dataset name: daily journal
# Unknown dataset name: jerusalem post
# Unknown dataset name: washington examiner
# Unknown dataset name: jerusalem post
# Unknown dataset name: orlando sentinel
# Unknown dataset name: windsor star the
# Unknown dataset name: canberra times the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Normalization failed for page tag: f.1.fro
# Unknown dataset name: national post
# Unknown dataset name: st. louis post - dispatch
# Unknown dataset name: philadelphia daily news
# Unknown dataset name: jerusalem post
# Unknown dataset name: observer the
# Unknown dataset name: jerusalem post
# Unknown dataset name: boston globe
# Unknown dataset name: waterloo region record
# Unknown dataset name: age the
# Unknown dataset name: jerusalem post
# Unknown dataset name: globe and mail the
# Unknown dataset name: jerusalem post
# Unknown dataset name: daily breeze
# Unknown dataset name: jerusalem post
# Unknown dataset name: daily telegraph the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: spectator the
# Unknown dataset name: belfast telegraph
# Unknown dataset name: globe and mail the
# Unknown dataset name: australian the
# Unknown dataset name: atlanta journal - constitution the
# Unknown dataset name: jerusalem post
# Unknown dataset name: home news tribune
# Unknown dataset name: windsor star the
# Unknown dataset name: evening gazette
# Unknown dataset name: daily mail
# Unknown dataset name: oakland post (1968-1981)
# Unknown dataset name: montreal gazette
# Unknown dataset name: indianapolis star
# Unknown dataset name: philadelphia inquirer
# Unknown dataset name: independent the
# Unknown dataset name: ottawa citizen the
# Unknown dataset name: sunday mercury
# Unknown dataset name: jerusalem post
# Unknown dataset name: baltimore sun the
# Unknown dataset name: leader post
# Unknown dataset name: vancouver sun the
# Unknown dataset name: daily herald
# Unknown dataset name: south florida sun - sentinel
# Unknown dataset name: boston globe
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: reforma
# Unknown dataset name: jerusalem post
# Unknown dataset name: china daily
# Unknown dataset name: australian the
# Unknown dataset name: jerusalem post
# Unknown dataset name: fort collins coloradoan
# Unknown dataset name: jerusalem post
# Unknown dataset name: huddersfield daily examiner
# Unknown dataset name: timaru herald
# Unknown dataset name: stock journal
# Unknown dataset name: boston globe
# Unknown dataset name: boston globe (pre-1997 fulltext)
# Unknown dataset name: australian financial review the
# Unknown dataset name: st. louis post - dispatch (pre-1997 fulltext)
# Unknown dataset name: jerusalem post
# Unknown dataset name: age the
# Unknown dataset name: jerusalem post
# Unknown dataset name: waterloo region record
# Unknown dataset name: globe and mail the
# Unknown dataset name: berlingske tidende
# Unknown dataset name: boston globe
# Unknown dataset name: forward
# Unknown dataset name: ottawa citizen the
# Unknown dataset name: daily telegraph the
# Unknown dataset name: jerusalem post
# Unknown dataset name: commercial appeal the
# Unknown dataset name: jerusalem post
# Unknown dataset name: telegraph-journal
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: china daily
# Unknown dataset name: london evening standard
# Unknown dataset name: ottawa citizen the
# Unknown dataset name: telegraph-journal
# Unknown dataset name: jewish exponent
# Unknown dataset name: temps  le
# Unknown dataset name: asheville citizen - times
# Unknown dataset name: boston globe
# Unknown dataset name: albuquerque journal
# Unknown dataset name: vancouver sun the
# Unknown dataset name: atlanta journal the
# Unknown dataset name: jerusalem post
# Unknown dataset name: gazette the
# Unknown dataset name: jerusalem post
# Unknown dataset name: newsday
# Unknown dataset name: mundo  el
# Unknown dataset name: new york amsterdam news
# Unknown dataset name: newsday
# Unknown dataset name: jerusalem post
# Unknown dataset name: new straits times
# Unknown dataset name: sydney morning herald
# Unknown dataset name: weekend australian
# Unknown dataset name: weekend australian
# Unknown dataset name: irish times
# Unknown dataset name: london free press the
# Unknown dataset name: dayton daily news
# Unknown dataset name: city a.m.
# Normalization failed for page tag: a11
# Unknown dataset name: waterloo region record
# Unknown dataset name: mural
# Unknown dataset name: age the
# Unknown dataset name: st. louis post - dispatch (pre-1997 fulltext)
# Unknown dataset name: china daily
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: chicago tribune (pre-1997 fulltext)
# Unknown dataset name: nanaimo daily news
# Unknown dataset name: ottawa citizen the
# Unknown dataset name: national post
# Unknown dataset name: winnipeg free press
# Unknown dataset name: china daily
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: dominion post
# Unknown dataset name: south florida sun - sentinel
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: orlando sentinel
# Unknown dataset name: monde  le
# Unknown dataset name: tampa bay times
# Unknown dataset name: toronto star
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: illawarra mercury
# Unknown dataset name: jerusalem post
# Unknown dataset name: australian the
# Unknown dataset name: australian the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: australian financial review the
# Unknown dataset name: post - crescent the
# Unknown dataset name: toronto star
# Unknown dataset name: toronto star
# Unknown dataset name: national post
# Unknown dataset name: presse die
# Unknown dataset name: record the
# Unknown dataset name: independent on sunday the
# Unknown dataset name: jerusalem post
# Unknown dataset name: irish times
# Unknown dataset name: record the
# Unknown dataset name: sarasota herald tribune
# Unknown dataset name: nottingham evening post
# Unknown dataset name: business the
# Unknown dataset name: boston globe
# Unknown dataset name: orlando sentinel
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: monde  le
# Unknown dataset name: christian science monitor, the
# Unknown dataset name: daily mail
# Unknown dataset name: milwaukee journal sentinel
# Unknown dataset name: national post
# Unknown dataset name: journal of commerce
# Unknown dataset name: boston globe
# Unknown dataset name: jerusalem post
# Unknown dataset name: telegram & gazette
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: ottawa citizen the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: nottingham evening post
# Unknown dataset name: south florida sun - sentinel
# Unknown dataset name: irish independent
# Unknown dataset name: morning call
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: gazette the
# Unknown dataset name: jerusalem post
# Unknown dataset name: newsday
# Unknown dataset name: china daily
# Unknown dataset name: boston globe
# Unknown dataset name: portland press herald
# Unknown dataset name: monde  le
# Unknown dataset name: observer
# Unknown dataset name: south florida sun - sentinel
# Unknown dataset name: jerusalem post
# Unknown dataset name: asian textile business
# Unknown dataset name: irish times
# Unknown dataset name: telegraph-journal
# Unknown dataset name: jerusalem post
# Unknown dataset name: forward
# Unknown dataset name: south florida sun - sentinel
# Unknown dataset name: jerusalem post
# Unknown dataset name: advertiser the
# Unknown dataset name: atlanta journal the atlanta constitution the
# Unknown dataset name: atlanta constitution the
# Unknown dataset name: boston globe (pre-1997 fulltext)
# Unknown dataset name: calgary herald
# Unknown dataset name: jerusalem post
# Unknown dataset name: north bay nugget
# Unknown dataset name: jerusalem post
# Unknown dataset name: deseret news
# Unknown dataset name: independent the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: new zealand herald the
# Unknown dataset name: times - news
# Unknown dataset name: irish times
# Unknown dataset name: times - transcript the
# Unknown dataset name: jewish exponent
# Unknown dataset name: jerusalem post
# Unknown dataset name: gazette the
# Unknown dataset name: scotsman the
# Unknown dataset name: australian the
# Unknown dataset name: lincoln journal star
# Unknown dataset name: montreal gazette
# Unknown dataset name: daily press
# Unknown dataset name: jerusalem post
# Unknown dataset name: boston globe (pre-1997 fulltext)
# Unknown dataset name: vancouver sun the
# Unknown dataset name: arizona republic
# Unknown dataset name: boston globe
# Unknown dataset name: province the
# Unknown dataset name: chicago tribune (pre-1997 fulltext)
# Unknown dataset name: timaru herald
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: gazette the
# Unknown dataset name: boston globe
# Unknown dataset name: daily telegraph the
# Normalization failed for page tag: t.6.8
# Unknown dataset name: courier post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: daily news
# Unknown dataset name: leader post
# Unknown dataset name: gazette the
# Unknown dataset name: jerusalem post
# Unknown dataset name: gazette the
# Unknown dataset name: london evening standard
# Unknown dataset name: jewish advocate
# Unknown dataset name: chronicle - herald
# Unknown dataset name: pensacola news journal
# Unknown dataset name: jewish advocate
# Unknown dataset name: ottawa citizen the
# Unknown dataset name: sunday independent
# Unknown dataset name: china daily
# Unknown dataset name: canberra times the
# Unknown dataset name: national post
# Unknown dataset name: jerusalem post
# Unknown dataset name: telegraph-journal
# Unknown dataset name: spectator the
# Unknown dataset name: middle east news online
# Unknown dataset name: irish times
# Unknown dataset name: vancouver sun the
# Unknown dataset name: columbian
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: milwaukee journal sentinel
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: toronto star
# Unknown dataset name: daily herald
# Unknown dataset name: monde  le
# Unknown dataset name: boston globe
# Unknown dataset name: jerusalem post
# Unknown dataset name: china daily
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: news press the
# Unknown dataset name: spectator the
# Unknown dataset name: courier - mail the
# Unknown dataset name: southland times the
# Unknown dataset name: pantagraph
# Unknown dataset name: china daily
# Unknown dataset name: waterloo region record
# Unknown dataset name: advertiser the
# Unknown dataset name: timaru herald
# Unknown dataset name: australian the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: bangor daily news
# Unknown dataset name: jewish advocate
# Unknown dataset name: jerusalem post
# Unknown dataset name: national post
# Unknown dataset name: jerusalem post
# Unknown dataset name: hartford courant
# Unknown dataset name: daily telegraph the
# Unknown dataset name: jewish advocate
# Unknown dataset name: northern advocate the
# Unknown dataset name: hartford courant
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: cincinnati enquirer
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: daily gleaner
# Unknown dataset name: australian the
# Unknown dataset name: peterborough examiner
# Unknown dataset name: china daily : european weekly
# Unknown dataset name: jerusalem post
# Unknown dataset name: daily sentinel review the
# Unknown dataset name: jerusalem post
# Unknown dataset name: atlanta journal the atlanta constitution the
# Unknown dataset name: consort enterprise
# Unknown dataset name: jerusalem post
# Unknown dataset name: post the
# Unknown dataset name: asbury park press
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: courier - mail the
# Unknown dataset name: argus leader
# Unknown dataset name: jerusalem post
# Unknown dataset name: gazette the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: portland press herald
# Unknown dataset name: jerusalem post
# Unknown dataset name: palabra
# Unknown dataset name: jerusalem post
# Unknown dataset name: detroit free press
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: philadelphia inquirer
# Unknown dataset name: dominion post
# Unknown dataset name: jerusalem post
# Unknown dataset name: poughkeepsie journal the
# Unknown dataset name: boston globe
# Unknown dataset name: jerusalem post
# Unknown dataset name: irish independent
# Unknown dataset name: globe and mail the
# Unknown dataset name: post and courier the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: age the
# Unknown dataset name: china daily
# Unknown dataset name: tampa bay times
# Unknown dataset name: jerusalem post
# Unknown dataset name: oakland tribune
# Unknown dataset name: forward
# Unknown dataset name: jewish exponent
# Unknown dataset name: city a.m.
# Unknown dataset name: china daily
# Unknown dataset name: daily telegraph the
# Unknown dataset name: echos  les
# Unknown dataset name: atlanta journal - constitution the
# Unknown dataset name: orlando sentinel
# Unknown dataset name: weekend australian
# Unknown dataset name: commercial appeal the
# Unknown dataset name: irish times
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: daily herald
# Unknown dataset name: ottawa citizen the
# Unknown dataset name: independent (daily edition) the
# Unknown dataset name: jerusalem post
# Unknown dataset name: guardian the
# Unknown dataset name: florida today
# Unknown dataset name: national post
# Unknown dataset name: globe and mail the
# Unknown dataset name: south wales echo
# Unknown dataset name: echos  les
# Unknown dataset name: jerusalem post
# Unknown dataset name: jewish exponent
# Unknown dataset name: herald the
# Unknown dataset name: jerusalem post
# Unknown dataset name: sunday star - times
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: boston globe
# Unknown dataset name: atlanta journal - constitution the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: toronto star
# Unknown dataset name: toronto star
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: pensacola news journal
# Unknown dataset name: newsday
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: guardian the
# Unknown dataset name: register - guard the
# Unknown dataset name: herald the
# Unknown dataset name: york daily record
# Unknown dataset name: jerusalem post
# Unknown dataset name: australian the
# Unknown dataset name: national post
# Unknown dataset name: irish times
# Unknown dataset name: jerusalem post
# Unknown dataset name: chicago tribune (pre-1997 fulltext)
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# ...
# Unknown dataset name: weekend australian
# Unknown dataset name: orlando sentinel
# Unknown dataset name: jerusalem post
# Unknown dataset name: echos  les
# Unknown dataset name: daily news
# Unknown dataset name: globe and mail the
# Unknown dataset name: tampa bay times
# Unknown dataset name: jerusalem post
# Unknown dataset name: sunday star - times
# Unknown dataset name: north bay nugget
# Unknown dataset name: irish times
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jewish advocate
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: blue mountains gazette
# Unknown dataset name: china daily : european weekly
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: western mail
# Unknown dataset name: australian the
# Unknown dataset name: daily press
# Unknown dataset name: indianapolis star
# Unknown dataset name: jewish exponent
# Unknown dataset name: desert sun the
# Unknown dataset name: globe and mail the
# Unknown dataset name: courier - mail the
# Unknown dataset name: jewish exponent
# Unknown dataset name: jerusalem post
# Unknown dataset name: weekend australian magazine, the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: australian financial review the
# Unknown dataset name: jerusalem post
# Unknown dataset name: des moines register
# Unknown dataset name: daily telegraph the
# Unknown dataset name: sunday herald - sun
# Unknown dataset name: philadelphia inquirer
# Unknown dataset name: jerusalem post
# Unknown dataset name: daily telegraph the
# Unknown dataset name: australian the
# Unknown dataset name: jerusalem post
# Unknown dataset name: edmonton journal
# Unknown dataset name: vancouver sun the
# Unknown dataset name: lincoln journal star
# Unknown dataset name: bay of plenty times
# Unknown dataset name: boston globe
# Unknown dataset name: spectator the
# Unknown dataset name: columbian
# Unknown dataset name: daily record
# Unknown dataset name: winnipeg sun the
# Unknown dataset name: daily herald
# Unknown dataset name: china daily
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: toronto star
# Unknown dataset name: jerusalem post
# Unknown dataset name: weekend australian
# Unknown dataset name: sunday gazette - mail
# Unknown dataset name: cape argus
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: news gazette
# Unknown dataset name: ottawa citizen the
# Unknown dataset name: national post
# Unknown dataset name: jerusalem post
# Unknown dataset name: times - tribune the
# Unknown dataset name: taranaki daily news
# Unknown dataset name: china daily
# Unknown dataset name: edmonton journal
# Unknown dataset name: intelligencer journal
# Unknown dataset name: australian financial review the
# Unknown dataset name: australian the
# Unknown dataset name: jerusalem post
# Unknown dataset name: orlando sentinel
# Unknown dataset name: jerusalem post
# Unknown dataset name: sunday independent
# Unknown dataset name: jewish advocate
# Unknown dataset name: daily gleaner
# Unknown dataset name: guardian the
# Unknown dataset name: florida today
# Unknown dataset name: scotsman the
# Unknown dataset name: stuart news the
# Unknown dataset name: jerusalem post
# Unknown dataset name: globe and mail the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: daily telegraph the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: australian financial review the
# Unknown dataset name: gazette the
# Unknown dataset name: jerusalem post
# Unknown dataset name: gazette the
# Unknown dataset name: jerusalem post
# Unknown dataset name: orlando sentinel
# Normalization failed for page tag: 0
# Unknown dataset name: sunday herald
# Unknown dataset name: stuart news the
# Unknown dataset name: philadelphia inquirer
# Unknown dataset name: jerusalem post
# Unknown dataset name: daily telegraph the
# Unknown dataset name: orlando sentinel
# Unknown dataset name: province the
# Unknown dataset name: middle east news online
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: newsday
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: monde  le
# Unknown dataset name: newsday
# Unknown dataset name: indianapolis star
# Unknown dataset name: newsday
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: globe and mail the
# Unknown dataset name: jerusalem post
# Unknown dataset name: gazette the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: dayton daily news
# Unknown dataset name: jerusalem post
# Unknown dataset name: intelligencer journal
# Unknown dataset name: boston globe
# Unknown dataset name: jerusalem post
# Unknown dataset name: sun times
# Unknown dataset name: australian the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jewish exponent
# Unknown dataset name: boston globe
# Unknown dataset name: national post
# Unknown dataset name: jewish advocate
# Unknown dataset name: christian science monitor, the
# Unknown dataset name: salinas californian the
# Unknown dataset name: evening sun the
# Unknown dataset name: manawatu standard
# Unknown dataset name: red river valley echo
# Unknown dataset name: rochester democrat and chronicle
# Unknown dataset name: hartford courant
# Unknown dataset name: stock and land
# Unknown dataset name: national post
# Unknown dataset name: naples daily news
# Unknown dataset name: windsor star the
# Unknown dataset name: welt die
# Unknown dataset name: gazette the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: australian the
# Unknown dataset name: statesman journal
# Unknown dataset name: jerusalem post
# Unknown dataset name: leader post
# Unknown dataset name: times - colonist
# Unknown dataset name: jerusalem post
# Unknown dataset name: philadelphia tribune
# Unknown dataset name: st. louis post - dispatch
# Unknown dataset name: tri - valley herald
# Unknown dataset name: coventry telegraph
# Unknown dataset name: jerusalem post
# Unknown dataset name: whitehorse star
# Unknown dataset name: temps  le
# Unknown dataset name: indianapolis star
# Unknown dataset name: taranaki daily news
# Unknown dataset name: globe and mail the
# Unknown dataset name: south florida sun - sentinel
# Unknown dataset name: vancouver sun the
# Unknown dataset name: tampa bay times
# Unknown dataset name: commercial appeal the
# Unknown dataset name: dayton daily news
# Unknown dataset name: jerusalem post
# Unknown dataset name: vancouver sun the
# Unknown dataset name: middle east news online
# Unknown dataset name: monde  le
# Unknown dataset name: globe and mail the
# Unknown dataset name: newsday
# Unknown dataset name: lancaster eagle - gazette
# Unknown dataset name: daily telegraph the
# Unknown dataset name: boston globe
# Unknown dataset name: daily telegraph the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: observer the
# Unknown dataset name: forward
# Normalization failed for page tag: d.1.fro
# Unknown dataset name: globe and mail the
# Unknown dataset name: deseret news
# Unknown dataset name: jerusalem post
# Unknown dataset name: windsor star the
# Unknown dataset name: advertiser the
# Unknown dataset name: jerusalem post
# Unknown dataset name: gazette the
# Unknown dataset name: waterloo region record
# Unknown dataset name: daily express
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: mail on sunday
# Unknown dataset name: boston globe
# Unknown dataset name: jewish exponent
# Unknown dataset name: chattanooga times free press
# Unknown dataset name: jerusalem post
# Unknown dataset name: philadelphia inquirer
# Unknown dataset name: jerusalem post
# Unknown dataset name: australian financial review the
# Unknown dataset name: jerusalem post
# Unknown dataset name: times - transcript the
# Unknown dataset name: jerusalem post
# Unknown dataset name: advertiser the
# Unknown dataset name: business the
# Unknown dataset name: jerusalem post
# Unknown dataset name: mercury the
# Unknown dataset name: jerusalem post
# Unknown dataset name: independent the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: prensa  la
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: press democrat the
# Unknown dataset name: boston globe
# Unknown dataset name: globe and mail the
# Unknown dataset name: bawaba  al
# Unknown dataset name: jerusalem post
# Unknown dataset name: standard - speaker
# Unknown dataset name: jerusalem post
# Unknown dataset name: daily review
# Unknown dataset name: china daily
# Unknown dataset name: kingston whig - standard
# Unknown dataset name: jerusalem post
# Unknown dataset name: new haven register
# Unknown dataset name: daily express
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: newsday
# Unknown dataset name: jerusalem post
# Unknown dataset name: boston globe
# Unknown dataset name: jerusalem post
# Unknown dataset name: sunday herald
# Unknown dataset name: jerusalem post
# Unknown dataset name: china daily
# Unknown dataset name: columbian
# Unknown dataset name: boston globe
# Normalization failed for page tag: a-3
# Unknown dataset name: jerusalem post
# Unknown dataset name: winnipeg sun the
# Unknown dataset name: jerusalem post
# Unknown dataset name: star tribune
# Unknown dataset name: irish times
# Unknown dataset name: vancouver sun the
# Unknown dataset name: waterloo region record
# Unknown dataset name: courier - mail the
# Unknown dataset name: detroit free press
# Unknown dataset name: jerusalem post
# Unknown dataset name: desert sun the
# Unknown dataset name: jerusalem post
# Unknown dataset name: newsday
# Unknown dataset name: city a.m.
# Unknown dataset name: jerusalem post
# Unknown dataset name: echos  les
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: presse die
# Unknown dataset name: gazette the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: edmonton sun the
# Unknown dataset name: christian science monitor, the
# Unknown dataset name: australian the
# Unknown dataset name: east bay times
# Unknown dataset name: sydney morning herald
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: china daily : european weekly
# Unknown dataset name: jerusalem post
# Unknown dataset name: presse die
# Unknown dataset name: jerusalem post
# Unknown dataset name: daily telegraph the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jewish exponent
# Unknown dataset name: presse die
# Unknown dataset name: toronto star
# Unknown dataset name: jerusalem post
# Unknown dataset name: ottawa citizen the
# Unknown dataset name: boston globe (pre-1997 fulltext)
# Unknown dataset name: globe and mail the
# Unknown dataset name: jerusalem post
# Unknown dataset name: globe and mail the
# Unknown dataset name: independent the
# Unknown dataset name: jerusalem post
# Unknown dataset name: evening sun the
# Unknown dataset name: middle east news online
# Unknown dataset name: south florida sun - sentinel
# Unknown dataset name: times - colonist
# Unknown dataset name: pittsburgh post - gazette
# Unknown dataset name: rochester democrat and chronicle
# Unknown dataset name: jerusalem post
# Unknown dataset name: south florida sun - sentinel
# Unknown dataset name: globe and mail the
# Unknown dataset name: australian the
# Unknown dataset name: leader post
# Unknown dataset name: spectator the
# Unknown dataset name: south florida sun - sentinel
# Unknown dataset name: australian the
# Unknown dataset name: jerusalem post
# Unknown dataset name: atlanta journal - constitution the
# Unknown dataset name: jewish advocate
# Unknown dataset name: boston globe
# Unknown dataset name: australian financial review the
# Unknown dataset name: jerusalem post
# Unknown dataset name: daily press
# Normalization failed for page tag: e-1
# Unknown dataset name: australian financial review the
# Unknown dataset name: monde  le
# Unknown dataset name: baltimore sun the
# Unknown dataset name: newsday
# Unknown dataset name: north york mirror the
# Unknown dataset name: ottawa sun the
# Unknown dataset name: sunday telegraph the
# Unknown dataset name: missoulian
# Unknown dataset name: tucson citizen
# Unknown dataset name: gazette the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: south florida sun - sentinel
# Unknown dataset name: ottawa citizen the
# Unknown dataset name: telegraph - herald
# Unknown dataset name: australian financial review the
# Unknown dataset name: toronto star
# Unknown dataset name: globe and mail the
# Unknown dataset name: jerusalem post
# Unknown dataset name: guardian the
# Unknown dataset name: independent (daily edition) the
# Unknown dataset name: daily mail
# Unknown dataset name: ottawa citizen the
# Unknown dataset name: san jose mercury news
# Unknown dataset name: hartford courant
# Unknown dataset name: milwaukee journal sentinel
# Unknown dataset name: jerusalem post
# Unknown dataset name: townsville bulletin
# Unknown dataset name: australian financial review the
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: news journal, the
# Unknown dataset name: asheville citizen - times
# Unknown dataset name: toronto star
# Unknown dataset name: orlando sentinel
# Unknown dataset name: jewish exponent
# Unknown dataset name: globe and mail the
# Unknown dataset name: south wales echo
# Unknown dataset name: jerusalem post
# Unknown dataset name: sydney morning herald
# Unknown dataset name: jerusalem post
# Unknown dataset name: portland press herald
# Unknown dataset name: jerusalem post
# Unknown dataset name: daily mail
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: chronicle - herald
# Unknown dataset name: western mail
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: new zealand herald the
# Unknown dataset name: expositor
# Unknown dataset name: jewish exponent
# Unknown dataset name: observer the
# Unknown dataset name: waterloo region record
# Unknown dataset name: north jersey herald news
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: jerusalem post
# Unknown dataset name: guardian the
# Unknown dataset name: jerusalem post
# Unknown dataset name: boston globe
# Unknown dataset name: edmonton journal
# Unknown dataset name: jewish advocate
# Unknown dataset name: irish times
# Unknown dataset name: south florida sun - sentinel
# Unknown dataset name: gravenhurst banner
# Normalization failed for page tag: b005
# Unknown dataset name: evansville courier & press
# Unknown dataset name: star tribune
# Unknown dataset name: niagara falls review
# Unknown dataset name: jerusalem post
# Unknown dataset name: china daily
# Unknown dataset name: philadelphia inquirer
# Unknown dataset name: boston globe (pre-1997 fulltext)
# Unknown dataset name: tampa bay times
# Unknown dataset name: jerusalem post
# Unknown dataset name: chicago tribune (pre-1997 fulltext)
# Unknown dataset name: ottawa citizen the
# Unknown dataset name: western mail
# Unknown dataset name: jerusalem post
# Unknown dataset name: welt kompakt
# Unknown dataset name: jerusalem post
# Unknown dataset name: jewish exponent
# Unknown dataset name: jerusalem post
# Unknown dataset name: irish times

# %%
combined_df.head()# shape#.head() #
# Out:
#    WordCount       GOID       Publisher       Date Section  Type  \
# 0        437  432768940  new york times 2004-05-02      14  news
# 1        826  434200392  new york times 2009-10-31       d  news
# 2       1022  433088214  new york times 2005-06-20       c  news
# 3        269  434140069  new york times 2009-07-01       a  news
# 4        658  899292469  new york times 2011-10-21       b  news
#
#                  Tags  Page  is_economic  bert_sentiment  salience_score  \
# 0                 NaN  14.8            1        0.722740             NaN
# 1  sports team owners   d.4            1        0.556584             NaN
# 2  news wire services   c.4            1        0.188518           0.471
# 3                 NaN   a.8            1       -1.287592           0.225
# 4    local government   b.3            1        0.399807           0.449
#
#    adjusted_sentiment bert_sentiment_label adjusted_sentiment_label  Year  \
# 0                 NaN             positive                  neutral  2004
# 1                 NaN             positive                  neutral  2009
# 2            0.305708              neutral                  neutral  2005
# 3           -0.213042             negative                  neutral  2009
# 4            0.591169              neutral                 positive  2011
#
#   Quarter
# 0  2004Q2
# 1  2009Q4
# 2  2005Q2
# 3  2009Q3
# 4  2011Q4

# %%
df = combined_df.copy()
df = df.reset_index()
print(df['Publisher'].unique())
publisher = df['Publisher'][0] #TODO
del df
print(publisher)
# Out:
# ['new york times']
# new york times

# %% [markdown]
# ### mean sentiment by quarter

# %%
def mean_sentiment_by_quarter(df):
    # Ensure the 'Date' column is in datetime format
    df['Date'] = pd.to_datetime(df['Date'])
    
    # Extract year and quarter from the 'Date' column
    df['Year'] = df['Date'].dt.year
    df['Quarter'] = df['Date'].dt.to_period('Q')
    
    # Group by 'Publisher' and 'Quarter' and calculate the mean sentiment for bert and adjusted sentiment
    result = df.groupby(['Quarter', 'Publisher'])[['adjusted_sentiment', 'bert_sentiment']].mean().reset_index()
    
    return result


df = mean_sentiment_by_quarter(combined_df)
#print(quarterly_sentiment['Publisher'].unique())
df = df[df['Publisher'] == publisher]
df.head()
#print(quarterly_sentiment[quarterly_sentiment['Publisher'] == 'usa today'])
# Out:
#   Quarter       Publisher  adjusted_sentiment  bert_sentiment
# 0  2004Q1  new york times            0.235069       -0.096671
# 1  2004Q2  new york times            0.236855       -0.056668
# 2  2004Q3  new york times            0.204994       -0.117809
# 3  2004Q4  new york times            0.209786       -0.102246
# 4  2005Q1  new york times            0.248484       -0.111161

# %%
# Ensure the 'Quarter' column is treated as a string
df['Quarter'] = df['Quarter'].astype(str)

# Set the size of the plot
plt.figure(figsize=(20, 10))

# Plot the data using matplotlib
plt.plot(df['Quarter'], df['bert_sentiment'], marker="o", label='bert_sentiment', color='green')
plt.plot(df['Quarter'], df['adjusted_sentiment'], marker="o", label='adjusted_sentiment')

# Customize the plot
plt.xlabel('Quarter', fontsize=14)
plt.ylabel('Mean Sentiment', fontsize=14)
plt.title(f'Mean Sentiment by Quarter for {publisher}', fontsize=16)
plt.xticks(rotation=45, fontsize=10)

# Display only every nth label on the x-axis
plt.gca().set_xticks(plt.gca().get_xticks()[::4])  # Change '4' to a different number if needed

# Add legend
plt.legend(title='Sentiment Type', fontsize=12)

plt.tight_layout()  # Adjust layout to prevent clipping of labels

# Show the plot
plt.show()

# %%
# Extract year and quarter from the 'Date' column

combined_df['Year'] = combined_df['Date'].dt.year

# Group by 'Publisher' and 'Quarter' and calculate the mean sentiment
result = combined_df.groupby(['Year', 'Publisher'])[['adjusted_sentiment', 'bert_sentiment']].mean().reset_index()
result.head()
# Out:
#    Year       Publisher  adjusted_sentiment  bert_sentiment
# 0  2004  new york times            0.221904       -0.093358
# 1  2005  new york times            0.197476       -0.052988
# 2  2006  new york times            0.194964        0.025607
# 3  2007  new york times            0.155684        0.004209
# 4  2008  new york times           -0.013710       -0.076671

# %%
# Group by Publisher, Year, and adjusted_sentiment_label and count occurrences
adjusted_sentiment_label = combined_df.groupby(['Publisher', 'Year', 'adjusted_sentiment_label']).size().reset_index(name='count_adjusted')

# Rename adjusted_sentiment_label column to 'label'
adjusted_sentiment_label = adjusted_sentiment_label.rename(columns={'adjusted_sentiment_label': 'label'})

# Group by Publisher, Year, and bert_sentiment_label and count occurrences
bert_sentiment_label = combined_df.groupby(['Publisher', 'Year', 'bert_sentiment_label']).size().reset_index(name='count_bert')

# Rename bert_sentiment_label column to 'label'
bert_sentiment_label = bert_sentiment_label.rename(columns={'bert_sentiment_label': 'label'})

# Merge the two DataFrames by Publisher, Year, and label
sentiment_counts = pd.merge(adjusted_sentiment_label, bert_sentiment_label, on=['Publisher', 'Year', 'label'], how='outer')

# Reshape the data for plotting both counts and label types
sentiment_counts_melted = pd.melt(
    sentiment_counts,
    id_vars=['Publisher', 'Year', 'label'],
    value_vars=['count_adjusted', 'count_bert'],
    var_name='count_type',
    value_name='Count'
)

# Define a custom color palette for sentiment labels
custom_palette = {'positive': 'green', 'negative': 'red', 'neutral': 'gray'}

# Set up the FacetGrid for each publisher and count type
g = sns.FacetGrid(sentiment_counts_melted, col='Publisher', row='count_type', 
                  height=5, aspect=2, sharey=True)

# Map the data to bar plots within each facet, using 'label' as hue to differentiate sentiment types
g.map_dataframe(sns.barplot, x='Year', y='Count', hue='label', palette=custom_palette)

# Customize the plot
g.add_legend(title='Sentiment Label')  # Add legend for sentiment labels
g.set_axis_labels('Year', 'Count of Articles')  # Set axis labels
g.set_xticklabels(rotation=45, fontsize=10)  # Rotate x-axis labels for readability

# Explicitly ensure all x-axis labels are displayed
for ax in g.axes.flat:
    ax.set_xticks(range(len(sentiment_counts['Year'].unique())))
    ax.set_xticklabels(sentiment_counts['Year'].unique(), rotation=45)

# Use publisher and count type as title for each subplot
g.set_titles('{col_name} - {row_name}')

# Adjust Layout to ensure labels fit
plt.subplots_adjust(top=0.9)
g.fig.suptitle('Count of Articles by Year, Sentiment Label, and Count Type')

# Show the plot
plt.show()

# %%
bert_sentiment_label#.head()
# Out:
#          Publisher  Year     label  count_bert
# 0   new york times  2004  negative        9582
# 1   new york times  2004   neutral        6521
# 2   new york times  2004  positive        5272
# 3   new york times  2005  negative        7897
# 4   new york times  2005   neutral        6515
# ..             ...   ...       ...         ...
# 58  new york times  2023   neutral        3199
# 59  new york times  2023  positive        1378
# 60  new york times  2024  negative        1093
# 61  new york times  2024   neutral        2023
# 62  new york times  2024  positive         921
#
# [63 rows x 4 columns]
